# %% [markdown]
# # MyHeartCounts - Daily Check Survey test script

# %% [markdown]
# # Using the DailyCheckSurveyDataset

# %%
from tasrif.data_readers.my_heart_counts import DailyCheckSurveyDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-fc07695c1c90> in <module>
# ----> 1 from tasrif.data_readers.my_heart_counts import DailyCheckSurveyDataset
#
# ModuleNotFoundError: No module named 'tasrif'

# %%
dcs = DailyCheckSurveyDataset(merge_activity_features=True)

# %%
dcs.raw_dataframe()
# Out:
#                                     recordId              appVersion  \
# 0       bc30a020-9eae-407d-b3f4-abff6433f554  version 1.0, build 5.1
# 1       9d7683ec-260e-4302-b171-ef122503ff36  version 1.0, build 5.1
# 2       f58b9847-17fb-4d5d-8766-ec8914887820  version 1.0, build 5.1
# 3       1dd59b8b-b8da-4980-a52a-0be60dc8cbf5  version 1.0, build 5.1
# 4       a650c6e9-0d19-4d05-b225-9330d8c569cf  version 1.0, build 5.1
# ...                                      ...                     ...
# 136530  32dcf16d-372c-4ee9-86c7-ee8b29710802  version 1.0, build 5.1
# 136531  a754e226-ae8d-464d-9454-6c994408abb5  version 1.0, build 5.1
# 136532  62a8b441-df91-4127-9d35-1aff755e699d  version 1.0, build 5.1
# 136533  25113d5d-4530-4c52-8ffc-df8f1c46e089  version 1.0, build 5.1
# 136534  27fbc4ca-903e-40ef-acce-e4a0686bdca0  version 1.0, build 5.1
#
#               phoneInfo                            healthCode      createdOn  \
# 0        iPhone 5 (GSM)  2df46170-9610-4060-b76b-baee8dc6db5e  1425948247000
# 1              iPhone 6  2ad7a007-ab25-41b1-ad70-a4390378e3be  1425963665000
# 2       iPhone 5s (GSM)  c73b0169-991d-4712-9391-c62d6f02d65b  1425961440000
# 3         iPhone 6 Plus  f3e0c587-7a61-4f73-8cd0-05bf4a16dda0  1425960156000
# 4         iPhone 6 Plus  4cf161c0-233e-49bb-b057-72ae061f64df  1425960204000
# ...                 ...                                   ...            ...
# 136530         iPhone 6  61ae941b-b636-4c2a-bb50-c615eb86018b  1437856558000
# 136531         iPhone 6  61ae941b-b636-4c2a-bb50-c615eb86018b  1439501330000
# 136532         iPhone 6  61ae941b-b636-4c2a-bb50-c615eb86018b  1438277235000
# 136533         iPhone 6  61ae941b-b636-4c2a-bb50-c615eb86018b  1438185439000
# 136534         iPhone 6  61ae941b-b636-4c2a-bb50-c615eb86018b  1438551099000
#
#         activity1_intensity activity1_option  activity1_time activity1_type  \
# 0                       1.0             True         18000.0              1
# 1                       NaN            False             NaN            NaN
# 2                       NaN            False             NaN            NaN
# 3                       1.0             True            60.0              1
# 4                       NaN            False             NaN            NaN
# ...                     ...              ...             ...            ...
# 136530                  NaN            False             NaN            NaN
# 136531                  NaN            False             NaN            NaN
# 136532                  NaN            False             NaN            NaN
# 136533                  NaN            False             NaN            NaN
# 136534                  NaN            False             NaN            NaN
#
#         activity2_intensity activity2_option  activity2_time activity2_type  \
# 0                       1.0             True          7260.0              1
# 1                       NaN              NaN             NaN            NaN
# 2                       NaN              NaN             NaN            NaN
# 3                       NaN            False             NaN            NaN
# 4                       NaN              NaN             NaN            NaN
# ...                     ...              ...             ...            ...
# 136530                  NaN              NaN             NaN            NaN
# 136531                  NaN              NaN             NaN            NaN
# 136532                  NaN              NaN             NaN            NaN
# 136533                  NaN              NaN             NaN            NaN
# 136534                  NaN              NaN             NaN            NaN
#
#         phone_on_user  sleep_time
# 0                 1.0     21600.0
# 1                 1.0     23400.0
# 2                 2.0     32400.0
# 3                 3.0     21600.0
# 4                 2.0     18000.0
# ...               ...         ...
# 136530            2.0        60.0
# 136531            2.0        60.0
# 136532            2.0     18000.0
# 136533            2.0     28800.0
# 136534            2.0     32400.0
#
# [136535 rows x 15 columns]

# %%
dcs.processed_dataframe()
# Out:
#                                     recordId  \
# 0       bc30a020-9eae-407d-b3f4-abff6433f554
# 1       9d7683ec-260e-4302-b171-ef122503ff36
# 2       f58b9847-17fb-4d5d-8766-ec8914887820
# 3       1dd59b8b-b8da-4980-a52a-0be60dc8cbf5
# 4       a650c6e9-0d19-4d05-b225-9330d8c569cf
# ...                                      ...
# 136530  32dcf16d-372c-4ee9-86c7-ee8b29710802
# 136531  a754e226-ae8d-464d-9454-6c994408abb5
# 136532  62a8b441-df91-4127-9d35-1aff755e699d
# 136533  25113d5d-4530-4c52-8ffc-df8f1c46e089
# 136534  27fbc4ca-903e-40ef-acce-e4a0686bdca0
#
#                                   healthCode      createdOn  \
# 0       2df46170-9610-4060-b76b-baee8dc6db5e  1425948247000
# 1       2ad7a007-ab25-41b1-ad70-a4390378e3be  1425963665000
# 2       c73b0169-991d-4712-9391-c62d6f02d65b  1425961440000
# 3       f3e0c587-7a61-4f73-8cd0-05bf4a16dda0  1425960156000
# 4       4cf161c0-233e-49bb-b057-72ae061f64df  1425960204000
# ...                                      ...            ...
# 136530  61ae941b-b636-4c2a-bb50-c615eb86018b  1437856558000
# 136531  61ae941b-b636-4c2a-bb50-c615eb86018b  1439501330000
# 136532  61ae941b-b636-4c2a-bb50-c615eb86018b  1438277235000
# 136533  61ae941b-b636-4c2a-bb50-c615eb86018b  1438185439000
# 136534  61ae941b-b636-4c2a-bb50-c615eb86018b  1438551099000
#
#         activity1_intensity  activity1_time  activity2_intensity  \
# 0                       1.0         18000.0                  1.0
# 1                       0.0             0.0                  0.0
# 2                       0.0             0.0                  0.0
# 3                       1.0            60.0                  0.0
# 4                       0.0             0.0                  0.0
# ...                     ...             ...                  ...
# 136530                  0.0             0.0                  0.0
# 136531                  0.0             0.0                  0.0
# 136532                  0.0             0.0                  0.0
# 136533                  0.0             0.0                  0.0
# 136534                  0.0             0.0                  0.0
#
#         activity2_time  sleep_time  activity_intensity  activity_time
# 0               7260.0     21600.0                 1.0        12630.0
# 1                  0.0     23400.0                 0.0            0.0
# 2                  0.0     32400.0                 0.0            0.0
# 3                  0.0     21600.0                 0.5           30.0
# 4                  0.0     18000.0                 0.0            0.0
# ...                ...         ...                 ...            ...
# 136530             0.0        60.0                 0.0            0.0
# 136531             0.0        60.0                 0.0            0.0
# 136532             0.0     18000.0                 0.0            0.0
# 136533             0.0     28800.0                 0.0            0.0
# 136534             0.0     32400.0                 0.0            0.0
#
# [136535 rows x 10 columns]

# %%
dcs.grouped_dataframe()
# Out:
#                                  healthCode  activity_intensity_mean  \
# 0      00040a4c-1b2d-470b-bff1-5c5f74da1f50                 0.000000
# 1      00050c3d-5c1b-453f-a86a-9bd64454a4e8                 0.000000
# 2      0008a86c-e4a4-4e3a-a539-a37a943f6d5f                 0.000000
# 3      000edcbb-9121-428c-bef3-7d93cbb31aa0                 0.000000
# 4      001109e0-ba68-4f50-b375-a92a62cf8b0e                 0.000000
# ...                                     ...                      ...
# 17617  fff5e159-8e0c-4451-b47a-14d345925d59                 1.000000
# 17618  fff8546a-4835-4279-8309-145e474c4a73                 1.000000
# 17619  fffc53a4-66b2-4dad-b061-9cf348fa6b27                 0.000000
# 17620  fffca717-aa4a-400c-9c19-02f05451bc88                 0.000000
# 17621  fffddf4f-ebac-4ae2-86bb-50651a59236e                 0.044776
#
#        activity_intensity_std  activity_time_mean  activity_time_std  \
# 0                    0.000000            0.000000           0.000000
# 1                    0.000000            0.000000           0.000000
# 2                    0.000000            0.000000           0.000000
# 3                         NaN            0.000000                NaN
# 4                         NaN            0.000000                NaN
# ...                       ...                 ...                ...
# 17617                     NaN         3150.000000                NaN
# 17618                0.816497         1575.000000        1537.042615
# 17619                0.000000            0.000000           0.000000
# 17620                0.000000            0.000000           0.000000
# 17621                0.189324          241.791045        1080.705333
#
#        sleep_time_mean  sleep_time_std
# 0         26400.000000     1859.032006
# 1         23760.000000     4282.545972
# 2            60.000000        0.000000
# 3            60.000000             NaN
# 4         35100.000000             NaN
# ...                ...             ...
# 17617     25260.000000             NaN
# 17618     25650.000000     3074.085230
# 17619     18531.428571     5954.470110
# 17620      5253.333333    10345.743086
# 17621     27622.388060     3041.402233
#
# [17622 rows x 7 columns]

# %%
from tasrif.data_readers.my_heart_counts import DailyCheckSurveyDataset

# %%
dcs = DailyCheckSurveyDataset(merge_activity_features=True)

# %%
dcs.raw_dataframe()
# Out:
#                                     recordId              appVersion  \
# 0       bc30a020-9eae-407d-b3f4-abff6433f554  version 1.0, build 5.1
# 1       9d7683ec-260e-4302-b171-ef122503ff36  version 1.0, build 5.1
# 2       f58b9847-17fb-4d5d-8766-ec8914887820  version 1.0, build 5.1
# 3       1dd59b8b-b8da-4980-a52a-0be60dc8cbf5  version 1.0, build 5.1
# 4       a650c6e9-0d19-4d05-b225-9330d8c569cf  version 1.0, build 5.1
# ...                                      ...                     ...
# 136530  32dcf16d-372c-4ee9-86c7-ee8b29710802  version 1.0, build 5.1
# 136531  a754e226-ae8d-464d-9454-6c994408abb5  version 1.0, build 5.1
# 136532  62a8b441-df91-4127-9d35-1aff755e699d  version 1.0, build 5.1
# 136533  25113d5d-4530-4c52-8ffc-df8f1c46e089  version 1.0, build 5.1
# 136534  27fbc4ca-903e-40ef-acce-e4a0686bdca0  version 1.0, build 5.1
#
#               phoneInfo                            healthCode      createdOn  \
# 0        iPhone 5 (GSM)  2df46170-9610-4060-b76b-baee8dc6db5e  1425948247000
# 1              iPhone 6  2ad7a007-ab25-41b1-ad70-a4390378e3be  1425963665000
# 2       iPhone 5s (GSM)  c73b0169-991d-4712-9391-c62d6f02d65b  1425961440000
# 3         iPhone 6 Plus  f3e0c587-7a61-4f73-8cd0-05bf4a16dda0  1425960156000
# 4         iPhone 6 Plus  4cf161c0-233e-49bb-b057-72ae061f64df  1425960204000
# ...                 ...                                   ...            ...
# 136530         iPhone 6  61ae941b-b636-4c2a-bb50-c615eb86018b  1437856558000
# 136531         iPhone 6  61ae941b-b636-4c2a-bb50-c615eb86018b  1439501330000
# 136532         iPhone 6  61ae941b-b636-4c2a-bb50-c615eb86018b  1438277235000
# 136533         iPhone 6  61ae941b-b636-4c2a-bb50-c615eb86018b  1438185439000
# 136534         iPhone 6  61ae941b-b636-4c2a-bb50-c615eb86018b  1438551099000
#
#         activity1_intensity activity1_option  activity1_time activity1_type  \
# 0                       1.0             True         18000.0              1
# 1                       NaN            False             NaN            NaN
# 2                       NaN            False             NaN            NaN
# 3                       1.0             True            60.0              1
# 4                       NaN            False             NaN            NaN
# ...                     ...              ...             ...            ...
# 136530                  NaN            False             NaN            NaN
# 136531                  NaN            False             NaN            NaN
# 136532                  NaN            False             NaN            NaN
# 136533                  NaN            False             NaN            NaN
# 136534                  NaN            False             NaN            NaN
#
#         activity2_intensity activity2_option  activity2_time activity2_type  \
# 0                       1.0             True          7260.0              1
# 1                       NaN              NaN             NaN            NaN
# 2                       NaN              NaN             NaN            NaN
# 3                       NaN            False             NaN            NaN
# 4                       NaN              NaN             NaN            NaN
# ...                     ...              ...             ...            ...
# 136530                  NaN              NaN             NaN            NaN
# 136531                  NaN              NaN             NaN            NaN
# 136532                  NaN              NaN             NaN            NaN
# 136533                  NaN              NaN             NaN            NaN
# 136534                  NaN              NaN             NaN            NaN
#
#         phone_on_user  sleep_time
# 0                 1.0     21600.0
# 1                 1.0     23400.0
# 2                 2.0     32400.0
# 3                 3.0     21600.0
# 4                 2.0     18000.0
# ...               ...         ...
# 136530            2.0        60.0
# 136531            2.0        60.0
# 136532            2.0     18000.0
# 136533            2.0     28800.0
# 136534            2.0     32400.0
#
# [136535 rows x 15 columns]

# %%
dcs.processed_dataframe()
# Out:
#                                     recordId  \
# 0       bc30a020-9eae-407d-b3f4-abff6433f554
# 1       9d7683ec-260e-4302-b171-ef122503ff36
# 2       f58b9847-17fb-4d5d-8766-ec8914887820
# 3       1dd59b8b-b8da-4980-a52a-0be60dc8cbf5
# 4       a650c6e9-0d19-4d05-b225-9330d8c569cf
# ...                                      ...
# 136530  32dcf16d-372c-4ee9-86c7-ee8b29710802
# 136531  a754e226-ae8d-464d-9454-6c994408abb5
# 136532  62a8b441-df91-4127-9d35-1aff755e699d
# 136533  25113d5d-4530-4c52-8ffc-df8f1c46e089
# 136534  27fbc4ca-903e-40ef-acce-e4a0686bdca0
#
#                                   healthCode      createdOn  \
# 0       2df46170-9610-4060-b76b-baee8dc6db5e  1425948247000
# 1       2ad7a007-ab25-41b1-ad70-a4390378e3be  1425963665000
# 2       c73b0169-991d-4712-9391-c62d6f02d65b  1425961440000
# 3       f3e0c587-7a61-4f73-8cd0-05bf4a16dda0  1425960156000
# 4       4cf161c0-233e-49bb-b057-72ae061f64df  1425960204000
# ...                                      ...            ...
# 136530  61ae941b-b636-4c2a-bb50-c615eb86018b  1437856558000
# 136531  61ae941b-b636-4c2a-bb50-c615eb86018b  1439501330000
# 136532  61ae941b-b636-4c2a-bb50-c615eb86018b  1438277235000
# 136533  61ae941b-b636-4c2a-bb50-c615eb86018b  1438185439000
# 136534  61ae941b-b636-4c2a-bb50-c615eb86018b  1438551099000
#
#         activity1_intensity  activity1_time  activity2_intensity  \
# 0                       1.0         18000.0                  1.0
# 1                       0.0             0.0                  0.0
# 2                       0.0             0.0                  0.0
# 3                       1.0            60.0                  0.0
# 4                       0.0             0.0                  0.0
# ...                     ...             ...                  ...
# 136530                  0.0             0.0                  0.0
# 136531                  0.0             0.0                  0.0
# 136532                  0.0             0.0                  0.0
# 136533                  0.0             0.0                  0.0
# 136534                  0.0             0.0                  0.0
#
#         activity2_time  sleep_time  activity_intensity  activity_time
# 0               7260.0     21600.0                 1.0        12630.0
# 1                  0.0     23400.0                 0.0            0.0
# 2                  0.0     32400.0                 0.0            0.0
# 3                  0.0     21600.0                 0.5           30.0
# 4                  0.0     18000.0                 0.0            0.0
# ...                ...         ...                 ...            ...
# 136530             0.0        60.0                 0.0            0.0
# 136531             0.0        60.0                 0.0            0.0
# 136532             0.0     18000.0                 0.0            0.0
# 136533             0.0     28800.0                 0.0            0.0
# 136534             0.0     32400.0                 0.0            0.0
#
# [136535 rows x 10 columns]

# %%
dcs.grouped_dataframe()
# Out:
#                                  healthCode  activity_intensity_mean  \
# 0      00040a4c-1b2d-470b-bff1-5c5f74da1f50                 0.000000
# 1      00050c3d-5c1b-453f-a86a-9bd64454a4e8                 0.000000
# 2      0008a86c-e4a4-4e3a-a539-a37a943f6d5f                 0.000000
# 3      000edcbb-9121-428c-bef3-7d93cbb31aa0                 0.000000
# 4      001109e0-ba68-4f50-b375-a92a62cf8b0e                 0.000000
# ...                                     ...                      ...
# 17617  fff5e159-8e0c-4451-b47a-14d345925d59                 1.000000
# 17618  fff8546a-4835-4279-8309-145e474c4a73                 1.000000
# 17619  fffc53a4-66b2-4dad-b061-9cf348fa6b27                 0.000000
# 17620  fffca717-aa4a-400c-9c19-02f05451bc88                 0.000000
# 17621  fffddf4f-ebac-4ae2-86bb-50651a59236e                 0.044776
#
#        activity_intensity_std  activity_time_mean  activity_time_std  \
# 0                    0.000000            0.000000           0.000000
# 1                    0.000000            0.000000           0.000000
# 2                    0.000000            0.000000           0.000000
# 3                         NaN            0.000000                NaN
# 4                         NaN            0.000000                NaN
# ...                       ...                 ...                ...
# 17617                     NaN         3150.000000                NaN
# 17618                0.816497         1575.000000        1537.042615
# 17619                0.000000            0.000000           0.000000
# 17620                0.000000            0.000000           0.000000
# 17621                0.189324          241.791045        1080.705333
#
#        sleep_time_mean  sleep_time_std
# 0         26400.000000     1859.032006
# 1         23760.000000     4282.545972
# 2            60.000000        0.000000
# 3            60.000000             NaN
# 4         35100.000000             NaN
# ...                ...             ...
# 17617     25260.000000             NaN
# 17618     25650.000000     3074.085230
# 17619     18531.428571     5954.470110
# 17620      5253.333333    10345.743086
# 17621     27622.388060     3041.402233
#
# [17622 rows x 7 columns]

# %%
dcs.participant_count()
# Out:
# 17622

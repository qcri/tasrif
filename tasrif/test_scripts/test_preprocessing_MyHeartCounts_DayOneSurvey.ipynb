# %% [markdown]
# # MyHeartCounts - Day One Survey

# %%
from tasrif.data_readers.my_heart_counts import DayOneSurveyDataset

# %%
dcs = DayOneSurveyDataset(mhc_folder='E:\\Development\\siha', drop_device_na=True, drop_labwork_na=True)

# %%
dcs.raw_dataframe()
# Out:
#                                    recordId               appVersion  \
# 0      08dd7805-eee5-4ad8-8ffa-4338742c8c72   version 1.0, build 5.1
# 1      b5291d98-d688-4d83-8c78-f104f1f6d3a0   version 1.0, build 5.1
# 2      d46981b5-f24b-4498-b228-532843e4a5a0   version 1.0, build 5.1
# 3      5bff2507-6ff7-4ff8-82b9-73f8cf7d75b7   version 1.0, build 5.1
# 4      5920822f-1220-44ab-b3e0-0190c8978e31   version 1.0, build 5.1
# ...                                     ...                      ...
# 25569  14061729-82a3-4cf9-9a4c-714b67fc760d  version 1.0.10, build 1
# 25570  6c92d9b9-9bbc-42a6-995d-d183c1d3f913  version 1.0.10, build 1
# 25571  63529017-1e5a-4438-9db2-9770fe58873c  version 1.0.10, build 1
# 25572  e19e3084-c726-4df5-b602-680582e3013c  version 1.0.10, build 1
# 25573  1c5385fa-fc85-49bc-b250-089105dcf2c7  version 1.0.10, build 1
#
#                   phoneInfo                            healthCode  \
# 0             iPhone 6 Plus  94fc492d-09d6-452c-b48b-4046f4d0b2d5
# 1      iPhone 5s (GSM+CDMA)  96494048-3c2e-460a-928c-cbe699cdf73e
# 2                  iPhone 6  14b52b68-5080-4898-86db-c07efabde713
# 3                  iPhone 6  395b5d38-dc39-40c1-84f8-c6c7ce0cb425
# 4             iPhone 6 Plus  9f0cd386-5be2-4c76-bd05-a9208e1b02b5
# ...                     ...                                   ...
# 25569             iPhone 4S  8b4ee972-a4f7-4fdb-8787-30bc0c397c21
# 25570              iPhone 6  3a839c5c-716e-40fe-a1cc-012346e98e13
# 25571         iPhone 6 Plus  7694769b-ca36-4921-a3fb-fc7230210096
# 25572              iPhone 6  88add059-835d-4a36-8c4c-3cad27d60a2c
# 25573             iPhone8,1  dcf9c3c7-92c9-4df2-8a7e-d3f9655e6582
#
#            createdOn device  labwork
# 0      1425930639000    2,1      2.0
# 1      1425948665000      1      2.0
# 2      1425960893000      1      2.0
# 3      1425957231000      1      2.0
# 4      1425935232000      1      2.0
# ...              ...    ...      ...
# 25569  1445935217000      1      2.0
# 25570  1445983653000      1      2.0
# 25571  1445945034000      1      2.0
# 25572  1445987982000      3      2.0
# 25573  1445949356000    1,3      NaN
#
# [25574 rows x 7 columns]

# %%
dcs.processed_dataframe()
# Out:
#                                    recordId               appVersion  \
# 0      08dd7805-eee5-4ad8-8ffa-4338742c8c72   version 1.0, build 5.1
# 1      b5291d98-d688-4d83-8c78-f104f1f6d3a0   version 1.0, build 5.1
# 2      d46981b5-f24b-4498-b228-532843e4a5a0   version 1.0, build 5.1
# 3      5bff2507-6ff7-4ff8-82b9-73f8cf7d75b7   version 1.0, build 5.1
# 4      5920822f-1220-44ab-b3e0-0190c8978e31   version 1.0, build 5.1
# ...                                     ...                      ...
# 25569  14061729-82a3-4cf9-9a4c-714b67fc760d  version 1.0.10, build 1
# 25570  6c92d9b9-9bbc-42a6-995d-d183c1d3f913  version 1.0.10, build 1
# 25571  63529017-1e5a-4438-9db2-9770fe58873c  version 1.0.10, build 1
# 25572  e19e3084-c726-4df5-b602-680582e3013c  version 1.0.10, build 1
# 25573  1c5385fa-fc85-49bc-b250-089105dcf2c7  version 1.0.10, build 1
#
#                   phoneInfo                            healthCode  \
# 0             iPhone 6 Plus  94fc492d-09d6-452c-b48b-4046f4d0b2d5
# 1      iPhone 5s (GSM+CDMA)  96494048-3c2e-460a-928c-cbe699cdf73e
# 2                  iPhone 6  14b52b68-5080-4898-86db-c07efabde713
# 3                  iPhone 6  395b5d38-dc39-40c1-84f8-c6c7ce0cb425
# 4             iPhone 6 Plus  9f0cd386-5be2-4c76-bd05-a9208e1b02b5
# ...                     ...                                   ...
# 25569             iPhone 4S  8b4ee972-a4f7-4fdb-8787-30bc0c397c21
# 25570              iPhone 6  3a839c5c-716e-40fe-a1cc-012346e98e13
# 25571         iPhone 6 Plus  7694769b-ca36-4921-a3fb-fc7230210096
# 25572              iPhone 6  88add059-835d-4a36-8c4c-3cad27d60a2c
# 25573             iPhone8,1  dcf9c3c7-92c9-4df2-8a7e-d3f9655e6582
#
#            createdOn device  labwork
# 0      1425930639000    2,1      2.0
# 1      1425948665000      1      2.0
# 2      1425960893000      1      2.0
# 3      1425957231000      1      2.0
# 4      1425935232000      1      2.0
# ...              ...    ...      ...
# 25569  1445935217000      1      2.0
# 25570  1445983653000      1      2.0
# 25571  1445945034000      1      2.0
# 25572  1445987982000      3      2.0
# 25573  1445949356000    1,3      NaN
#
# [25574 rows x 7 columns]

# %%
DayOneSurveyDataset.device_mapping
# Out:
# {'iPhone': '1',
#  'ActivityBand': '2',
#  'Pedometer': '2',
#  'SmartWatch': '3',
#  'AppleWatch': '3',
#  'Other': 'Other'}

# %%
dcs.participant_count()
# Out:
# 22717

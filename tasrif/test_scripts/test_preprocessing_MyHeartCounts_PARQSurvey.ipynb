# %% [markdown]
# # MyHeartCounts - Physical Activity Readiness Questionnaire

# %%
from tasrif.data_readers.my_heart_counts import PARQSurveyDataset

# %%
parq = PARQSurveyDataset()

# %%
parq.raw_dataframe()
# Out:
#                                    recordId               appVersion  \
# 0      90bbe279-1485-4ccb-b7f4-f78e822512ec   version 1.0, build 5.1
# 1      871bf617-64b4-4daa-9ff3-64c183c6888d   version 1.0, build 5.1
# 2      ed2ceaa2-9122-41c4-b570-8a339f7dbdce   version 1.0, build 5.1
# 3      670ddabb-e49c-48c6-8615-bcd930873490   version 1.0, build 5.1
# 4      96f02a50-4a4d-49bd-920a-8d3ddb68998a   version 1.0, build 5.1
# ...                                     ...                      ...
# 25810  4a9240be-ecee-4a5d-b07f-dc8d3bb5cf1e  version 1.0.10, build 1
# 25811  d727ffb2-a390-4396-babf-9a03bb269820  version 1.0.10, build 1
# 25812  a9785601-ae46-4db1-a873-4012a550d686  version 1.0.10, build 1
# 25813  77cfd6a4-7490-4757-b578-2d53da75e9f9  version 1.0.10, build 1
# 25814  c57f0201-0ee1-4a40-86c2-c5a2c50839a3  version 1.0.10, build 1
#
#                   phoneInfo                            healthCode  \
# 0             iPhone 6 Plus  ceb60f6c-d7c1-4fe0-a2bd-01e6de0cae19
# 1      iPhone 5s (GSM+CDMA)  4c8ae705-217c-45a7-a188-1810a0ebb59c
# 2             iPhone 6 Plus  98609d3d-fe46-4e15-a39b-09840a9943a7
# 3                  iPhone 6  234acdb6-c223-4b68-a189-46ed5d5d01e3
# 4                  iPhone 6  a5a06622-7142-487e-8682-863b75d5e26c
# ...                     ...                                   ...
# 25810             iPhone8,1  dcf9c3c7-92c9-4df2-8a7e-d3f9655e6582
# 25811         iPhone 6 Plus  7694769b-ca36-4921-a3fb-fc7230210096
# 25812              iPhone 6  0934f164-1a90-4ebe-a708-fcc71ee749a8
# 25813         iPhone 6 Plus  5342a6b2-7ba5-4b77-af75-e07b05000ab1
# 25814              iPhone 6  fd5394ab-b6be-4a9e-8be1-dffb72a22fc8
#
#            createdOn chestPain chestPainInLastMonth dizziness heartCondition  \
# 0      1425961340000     False                False     False          False
# 1      1425961464000     False                False     False          False
# 2      1425944620000     False                False     False          False
# 3      1425946833000     False                False     False          False
# 4      1425930444000      True                False     False          False
# ...              ...       ...                  ...       ...            ...
# 25810  1445949448000     False                False     False          False
# 25811  1445945091000     False                 True     False          False
# 25812  1445967828000     False                False     False          False
# 25813  1445933440000     False                False     False          False
# 25814  1445978037000     False                False     False          False
#
#       jointProblem physicallyCapable prescriptionDrugs
# 0            False              True             False
# 1            False             False             False
# 2            False             False              True
# 3            False             False             False
# 4             True             False             False
# ...            ...               ...               ...
# 25810         True             False             False
# 25811        False             False              True
# 25812         True             False             False
# 25813        False             False             False
# 25814         True             False             False
#
# [25815 rows x 12 columns]

# %%
parq.processed_dataframe()
# Out:
#                                    recordId               appVersion  \
# 1      871bf617-64b4-4daa-9ff3-64c183c6888d   version 1.0, build 5.1
# 2      ed2ceaa2-9122-41c4-b570-8a339f7dbdce   version 1.0, build 5.1
# 3      670ddabb-e49c-48c6-8615-bcd930873490   version 1.0, build 5.1
# 4      96f02a50-4a4d-49bd-920a-8d3ddb68998a   version 1.0, build 5.1
# 5      ee0137bc-e490-4d1c-be86-51fb5ba065d8   version 1.0, build 5.1
# ...                                     ...                      ...
# 25810  4a9240be-ecee-4a5d-b07f-dc8d3bb5cf1e  version 1.0.10, build 1
# 25811  d727ffb2-a390-4396-babf-9a03bb269820  version 1.0.10, build 1
# 25812  a9785601-ae46-4db1-a873-4012a550d686  version 1.0.10, build 1
# 25813  77cfd6a4-7490-4757-b578-2d53da75e9f9  version 1.0.10, build 1
# 25814  c57f0201-0ee1-4a40-86c2-c5a2c50839a3  version 1.0.10, build 1
#
#                   phoneInfo                            healthCode  \
# 1      iPhone 5s (GSM+CDMA)  4c8ae705-217c-45a7-a188-1810a0ebb59c
# 2             iPhone 6 Plus  98609d3d-fe46-4e15-a39b-09840a9943a7
# 3                  iPhone 6  234acdb6-c223-4b68-a189-46ed5d5d01e3
# 4                  iPhone 6  a5a06622-7142-487e-8682-863b75d5e26c
# 5             iPhone 6 Plus  a0d4d2bf-9b19-47bf-ab9b-32fa5601127c
# ...                     ...                                   ...
# 25810             iPhone8,1  dcf9c3c7-92c9-4df2-8a7e-d3f9655e6582
# 25811         iPhone 6 Plus  7694769b-ca36-4921-a3fb-fc7230210096
# 25812              iPhone 6  0934f164-1a90-4ebe-a708-fcc71ee749a8
# 25813         iPhone 6 Plus  5342a6b2-7ba5-4b77-af75-e07b05000ab1
# 25814              iPhone 6  fd5394ab-b6be-4a9e-8be1-dffb72a22fc8
#
#            createdOn chestPain chestPainInLastMonth dizziness heartCondition  \
# 1      1425961464000     False                False     False          False
# 2      1425944620000     False                False     False          False
# 3      1425946833000     False                False     False          False
# 4      1425930444000      True                False     False          False
# 5      1425951385000      True                False     False           True
# ...              ...       ...                  ...       ...            ...
# 25810  1445949448000     False                False     False          False
# 25811  1445945091000     False                 True     False          False
# 25812  1445967828000     False                False     False          False
# 25813  1445933440000     False                False     False          False
# 25814  1445978037000     False                False     False          False
#
#       jointProblem physicallyCapable prescriptionDrugs
# 1            False             False             False
# 2            False             False              True
# 3            False             False             False
# 4             True             False             False
# 5            False             False              True
# ...            ...               ...               ...
# 25810         True             False             False
# 25811        False             False              True
# 25812         True             False             False
# 25813        False             False             False
# 25814         True             False             False
#
# [23850 rows x 12 columns]

# %%
parq.participant_count()
# Out:
# 23990
